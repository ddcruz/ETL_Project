# %%
import pandas as pd
from datetime import date
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Extract CSV of Northern Hemisphere Ice Extents to pandas Dataframe

# %%
csv_file1 = "./Resources/noaa/G02135/north/daily/data/N_seaice_extent_daily_v3.0.csv"
n_seaice_df = pd.read_csv(csv_file1, header=1)
n_seaice_df.columns = ['year', 'month', 'day', 'north_icearea_sq_km', 'missing', 'source_data']
# n_seaice_df = n_seaice_df.drop(columns=['source_data', 'missing'])
n_seaice_df.head()
# Out:
#    year  month  day  north_icearea_sq_km  missing  \
# 0  1978     10   26               10.231      0.0
# 1  1978     10   28               10.420      0.0
# 2  1978     10   30               10.557      0.0
# 3  1978     11    1               10.670      0.0
# 4  1978     11    3               10.777      0.0
#
#                                          source_data
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...

# %% [markdown]
# ### Extract CSV of Southern Hemisphere Ice Extents to pandas Dataframe

# %%
csv_file2 = './Resources/noaa/G02135/south/daily/data/S_seaice_extent_daily_v3.0.csv'
s_seaice_df = pd.read_csv(csv_file2, header=1)
s_seaice_df.columns = ['year', 'month', 'day', 'south_icearea_sq_km', 'missing', 'source_data']
# s_seaice_df = s_seaice_df.drop(columns=['source_data', 'missing'])
s_seaice_df.head()
# Out:
#    year  month  day  south_icearea_sq_km  missing  \
# 0  1978     10   26               17.624      0.0
# 1  1978     10   28               17.803      0.0
# 2  1978     10   30               17.670      0.0
# 3  1978     11    1               17.527      0.0
# 4  1978     11    3               17.486      0.0
#
#                                          source_data
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...

# %% [markdown]
# ### Confirm Data types

# %%
s_seaice_df.dtypes
# Out:
# year                     int64
# month                    int64
# day                      int64
# south_icearea_sq_km    float64
# missing                float64
# source_data             object
# dtype: object

# %% [markdown]
# ### Create inline function to combine first three columns to one "date_time" column

# %%
n_seaice_df["date_time"] = n_seaice_df.apply(lambda row :
                          date(row.year, row.month, row.day),
                          axis=1
                          )

n_seaice_df.head()
# Out:
#    year  month  day  north_icearea_sq_km  missing  \
# 0  1978     10   26               10.231      0.0
# 1  1978     10   28               10.420      0.0
# 2  1978     10   30               10.557      0.0
# 3  1978     11    1               10.670      0.0
# 4  1978     11    3               10.777      0.0
#
#                                          source_data   date_time
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-10-26
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-10-28
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-10-30
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-11-01
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-11-03

# %%
s_seaice_df["date_time"] = n_seaice_df.apply(lambda row :
                          date(row.year, row.month, row.day),
                          axis=1
                          )

s_seaice_df.head()
# Out:
#    year  month  day  south_icearea_sq_km  missing  \
# 0  1978     10   26               17.624      0.0
# 1  1978     10   28               17.803      0.0
# 2  1978     10   30               17.670      0.0
# 3  1978     11    1               17.527      0.0
# 4  1978     11    3               17.486      0.0
#
#                                          source_data   date_time
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-10-26
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-10-28
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-10-30
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-11-01
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...  1978-11-03

# %% [markdown]
# ### Convert "date_time" column to actual "date_time" data type for grouping functions below

# %%
n_seaice_df["date_time"] = pd.to_datetime(n_seaice_df["date_time"])
n_seaice_df.head()
# Out:
#    year  month  day  north_icearea_sq_km  missing  \
# 0  1978     10   26               10.231      0.0
# 1  1978     10   28               10.420      0.0
# 2  1978     10   30               10.557      0.0
# 3  1978     11    1               10.670      0.0
# 4  1978     11    3               10.777      0.0
#
#                                          source_data  date_time
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-26
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-28
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-30
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-11-01
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-11-03

# %%
s_seaice_df["date_time"] = pd.to_datetime(s_seaice_df["date_time"])
s_seaice_df.head()
# Out:
#    year  month  day  south_icearea_sq_km  missing  \
# 0  1978     10   26               17.624      0.0
# 1  1978     10   28               17.803      0.0
# 2  1978     10   30               17.670      0.0
# 3  1978     11    1               17.527      0.0
# 4  1978     11    3               17.486      0.0
#
#                                          source_data  date_time
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-26
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-28
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-30
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-11-01
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-11-03

# %% [markdown]
# ### Merge the northern and southern dataframes

# %%
merged_df = n_seaice_df.merge(s_seaice_df, on="date_time", how="left")
merged_df.head()
# Out:
#    year_x  month_x  day_x  north_icearea_sq_km  missing_x  \
# 0    1978       10     26               10.231        0.0
# 1    1978       10     28               10.420        0.0
# 2    1978       10     30               10.557        0.0
# 3    1978       11      1               10.670        0.0
# 4    1978       11      3               10.777        0.0
#
#                                        source_data_x  date_time  year_y  \
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-26    1978
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-28    1978
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-10-30    1978
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-11-01    1978
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid... 1978-11-03    1978
#
#    month_y  day_y  south_icearea_sq_km  missing_y  \
# 0       10     26               17.624        0.0
# 1       10     28               17.803        0.0
# 2       10     30               17.670        0.0
# 3       11      1               17.527        0.0
# 4       11      3               17.486        0.0
#
#                                        source_data_y
# 0   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 1   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 2   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 3   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...
# 4   ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...

# %% [markdown]
# ### Extract only the required columns from the merged dataframe

# %%
final_merged_df = merged_df[['date_time', 'north_icearea_sq_km', 'south_icearea_sq_km']]
final_merged_df.head()
# Out:
#    date_time  north_icearea_sq_km  south_icearea_sq_km
# 0 1978-10-26               10.231               17.624
# 1 1978-10-28               10.420               17.803
# 2 1978-10-30               10.557               17.670
# 3 1978-11-01               10.670               17.527
# 4 1978-11-03               10.777               17.486

# %% [markdown]
# ### Sort the "date_time" column by year and aggregate the north and south columns by the max value

# %%
sorted_df = final_merged_df.groupby(pd.Grouper(key='date_time', freq='Y')).agg({'north_icearea_sq_km' : 'max','south_icearea_sq_km' : 'max'})
sorted_df.reset_index(inplace=True)
sorted_df.head()
# Out:
#    date_time  north_icearea_sq_km  south_icearea_sq_km
# 0 1978-12-31               14.585               17.803
# 1 1979-12-31               16.635               18.361
# 2 1980-12-31               16.302               19.092
# 3 1981-12-31               15.801               18.856
# 4 1982-12-31               16.325               18.550

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "pythonuser:password@127.0.0.1/global_temp_sea_ice_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['global_temp', 'sea_ice']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
sorted_df.to_sql(name='sea_ice', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from sea_ice', con=engine).head()
# Out:
#     date_time  north_icearea_sq_km  south_icearea_sq_km
# 0  1978-12-31               14.585               17.803
# 1  1979-12-31               16.635               18.361
# 2  1980-12-31               16.302               19.092
# 3  1981-12-31               15.801               18.856
# 4  1982-12-31               16.325               18.550
